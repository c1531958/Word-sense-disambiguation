# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv("correlation.csv")

# %%
df.head()
# Out:
#   Training data  Training Dataset length   F-Score      RMSE  Accuracy
# 0          Hood                      171  0.826414  0.594692  0.865854
# 1          Java                     4504  0.984172  0.122612  0.984966
# 2          Mole                      480  0.864607  0.818476  0.864078
# 3       Pitcher                     6421  0.580961  0.180653  0.967364
# 4         Pound                      186  0.727528  0.287183  0.917526

# %%
pearsoncorr = df.corr(method='pearson')

# %%
pearsoncorr
# Out:
#                          Training Dataset length   F-Score      RMSE  Accuracy
# Training Dataset length                 1.000000 -0.383176 -0.585130  0.742303
# F-Score                                -0.383176  1.000000  0.152050 -0.108055
# RMSE                                   -0.585130  0.152050  1.000000 -0.909059
# Accuracy                                0.742303 -0.108055 -0.909059  1.000000

# %%
#f-score pvalue
pearsonr([171,4504,480,6421,186,875,1064,508,164,144],[0.826414,0.984172,0.864607,0.580961,0.727528,0.834892,0.897631
,0.836855,0.876645,0.873016])
# Out:
# (-0.38317600273004293, 0.27440734098266634)

# %%
#rmse p-value
pearsonr([171,4504,480,6421,186,875,1064,508,164,144],[0.594692,0.122612
,0.818476,0.180653,0.287183,0.589158,0.388567,0.705397,0.455842,0.235702])
# Out:
# (-0.5851299838792912, 0.07557528497951935)

# %%
#accuracy pvalue
pearsonr([171,4504,480,6421,186,875,1064,508,164,144],[0.865854,0.984966,0.864078,0.967364,0.917526,0.889807,0.901532,0.89372
,0.909091,0.944444])
# Out:
# (0.7423029530700566, 0.01394443618466527)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            annot=True,
            linewidth=0.5)

# %%
ax1 = df.plot.scatter(x='Training Dataset length',
                      y='F-Score', figsize=(15,15),
                      c='Blue')

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
plt.figure(figsize=(15,8))
ax = sns.regplot(x="Training Dataset length", y="F-Score", data=df )

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(x="Training Dataset length", y="RMSE", data=df )

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(x="Training Dataset length", y="Accuracy", data=df )
