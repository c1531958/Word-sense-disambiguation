# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv("lstm_corr.csv")

# %%
df.head()
# Out:
#   Training data  Dataset length   F-Score      RMSE  Accuracy
# 0          Hood             171  0.857599  0.506061  0.890244
# 1          Java            4504  0.993455  0.078872  0.993779
# 2          Mole             480  0.884508  0.850471  0.893204
# 3       Pitcher            6421  0.686611  0.059560  0.996453
# 4         Pound             186  0.566319  0.304604  0.907216

# %%
pearsoncorr = df.corr(method='pearson')

# %%
pearsoncorr
# Out:
#                 Dataset length   F-Score      RMSE  Accuracy
# Dataset length        1.000000 -0.069156 -0.594570  0.756783
# F-Score              -0.069156  1.000000 -0.043412  0.257536
# RMSE                 -0.594570 -0.043412  1.000000 -0.893051
# Accuracy              0.756783  0.257536 -0.893051  1.000000

# %%
#Fscore pvalue
pearsonr([171,4504,480,6421,186,875,1064,508,164,144],[0.857599,0.993455,0.884508,0.686611,0.566319,0.901391
,0.937098,0.746897,0.910006,0.909053])
# Out:
# (-0.06915641853361676, 0.8494417723324409)

# %%
#RMSE pvalue
pearsonr([171,4504,480,6421,186,875,1064,508,164,144],[0.506061,0.078872,0.850471,0.05956,0.304604,0.409932
,0.317264,0.900885,0.426401,0.204124])
# Out:
# (-0.594570002408469, 0.06984950896439085)

# %%
#Accuracy pvalue
pearsonr([171,4504,480,6421,186,875,1064,508,164,144],[0.890244,0.993779,0.893204,0.996453,0.907216,
                                                       0.939394,0.938731,0.864734,0.935065,0.958333])
# Out:
# (0.756783467382504, 0.011278075282566807)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            annot=True,
            linewidth=0.5)

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(x="Dataset length", y="F-Score", data=df )

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(x="Dataset length", y="RMSE", data=df )

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(x="Dataset length", y="Accuracy", data=df )
